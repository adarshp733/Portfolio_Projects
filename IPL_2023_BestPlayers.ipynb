# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.crictracker.com/ipl-orange-cap/"

page = requests.get(url)

print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text,"html")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    IPL Orange Cap 2023: Most Runs in IPL 2023 - CricTracker
#   </title>
#   <link href="https://www.crictracker.com/ipl-orange-cap/" rel="canonical"/>
#   <link href="https://www.crictracker.com/ipl-orange-cap/?amp=1" id="ampURL" rel="amphtml"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=2" name="viewport"/>
#   <meta content="CricTracker" name="Author"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="2023 IPL Orange Cap: Check out the latest rankings of IPL 2023 Orange cap holder list with the most runs scored, strike rate, 4's, &amp; 6's and more updates on CricTracker" name="description"/>
#   <meta content="IPL Orange Cap, IPL Orange Cap 2023, Orange Cap Holder List in IPL 2023, IPL Most Runs" name="keywords"/>
#   <meta content="Follow, Index" name="robots"/>
# ...

# %%
table = soup.find("table", class_="numbered undefined undefined text-center font-semi text-nowrap table")

title = table.find_all("th")
print(title)
# Out:
# [<th class="">No</th>, <th class="">Player</th>, <th class="">Team</th>, <th class="">R</th>, <th class="">Mat</th>, <th class="">BF</th>, <th class="">Avg</th>, <th class="">H.S</th>, <th class="">SR</th>, <th class="">4s</th>, <th class="">6s</th>, <th class="">100s</th>, <th class="">50s</th>]

# %%
header = []
for i in title:
    name = i.text
    header.append(name)

print(header)
# Out:
# ['No', 'Player', 'Team', 'R', 'Mat', 'BF', 'Avg', 'H.S', 'SR', '4s', '6s', '100s', '50s']

# %%
df = pd.DataFrame(columns=header)
df
# Out:
# Empty DataFrame
# Columns: [No, Player, Team, R, Mat, BF, Avg, H.S, SR, 4s, 6s, 100s, 50s]
# Index: []

# %%
rows = table.find_all("tr")

for i in rows[1:]:
    data = i.find_all("td")
    row = [tr.text for tr in data]
    l = len(df)
    df.loc[l] = row

df
# Out:
#     No            Player Team    R Mat   BF    Avg  H.S      SR  4s  6s 100s  \
# 0    1      Shubman Gill   GT  890  17  564  59.33  129   157.8  85  33    3
# 1    2    Faf du Plessis  RCB  730  14  475  56.15   84  153.68  60  36   --
# 2    3      Devon Conway  CSK  672  16  481  51.69   92  139.71  77  18   --
# 3    4       Virat Kohli  RCB  639  14  457  53.25  101  139.82  65  16    2
# 4    5  Yashasvi Jaiswal   RR  625  14  382  48.08  124  163.61  82  26    1
# 5    6  Suryakumar Yadav   MI  605  16  334  43.21  103  181.14  65  28    1
# 6    7   Ruturaj Gaikwad  CSK  590  16  400  42.14   92   147.5  46  30   --
# 7    8      David Warner   DC  516  14  392  36.86   86  131.63  69  10   --
# 8    9       Rinku Singh  KKR  474  14  317  59.25   67  149.53  31  29   --
# 9   10      Ishan Kishan   MI  454  16  318  30.27   75  142.77  54  18   --
# 10  11     Cameron Green   MI  452  16  282  50.22  100  160.28  40  22    1
# ...

# %%
df.set_index("No", inplace=True)
df
# Out:
#               Player Team    R Mat   BF    Avg  H.S      SR  4s  6s 100s 50s
# No
# 1       Shubman Gill   GT  890  17  564  59.33  129   157.8  85  33    3   4
# 2     Faf du Plessis  RCB  730  14  475  56.15   84  153.68  60  36   --   8
# 3       Devon Conway  CSK  672  16  481  51.69   92  139.71  77  18   --   6
# 4        Virat Kohli  RCB  639  14  457  53.25  101  139.82  65  16    2   6
# 5   Yashasvi Jaiswal   RR  625  14  382  48.08  124  163.61  82  26    1   5
# 6   Suryakumar Yadav   MI  605  16  334  43.21  103  181.14  65  28    1   5
# 7    Ruturaj Gaikwad  CSK  590  16  400  42.14   92   147.5  46  30   --   4
# 8       David Warner   DC  516  14  392  36.86   86  131.63  69  10   --   6
# 9        Rinku Singh  KKR  474  14  317  59.25   67  149.53  31  29   --   4
# 10      Ishan Kishan   MI  454  16  318  30.27   75  142.77  54  18   --   3
# 11     Cameron Green   MI  452  16  282  50.22  100  160.28  40  22    1   2
# ...

# %%
df.to_csv(r'D:\STUDY MATERIAL\Data Analytics\IPL_2023_BestPlayers.csv', index=False);
